# %%
import pandas as pd

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import cross_val_score, KFold
import numpy as np

from sklearn.model_selection import GridSearchCV
import matplotlib.pyplot as plt

# %%
pd.set_option("display.max_columns", None)

# %%
survey = pd.read_csv(r"C:\Users\Peter\OneDrive\Desktop\Code and Projects\ECO1465\clean survey.csv")

# %%
survey
# Out:
#        Unnamed: 0         ResponseId     treatment matchTreatment  \
# 0               1  R_0006zeOG7m4r5bX       Liberal        Counter
# 1               2  R_000QuLyZsff11wl       Control        Control
# 2               3  R_006vNO79PBEQJK9       Liberal        Counter
# 3               4  R_00QUYdXn0LIx6sF       Control        Control
# 4               5  R_00VWiXSyP4IFidX       Control        Control
# ...           ...                ...           ...            ...
# 17630       17631  R_zf2l1Hew4SGGGpr  Conservative            Pro
# 17631       17632  R_zfeiEbwrxA57jrP       Control        Control
# 17632       17633  R_zfiOvlmPfCMWNRn  Conservative        Counter
# 17633       17634  R_zfj2X1JcX4Yc2Qx       Control        Control
# 17634       17635  R_zflZX23gkgzR2V3       Control        Control
#
#          treatIdeo  control  \
# 0      treatLIdeoC    False
# 1          control     True
# 2      treatLIdeoC    False
# 3          control     True
# ...

# %%
survey.describe()
# Out:
#          Unnamed: 0   newLikesNum  installTwoWeeks  minHistoryRelative  \
# count  17635.000000  17635.000000     17635.000000         1492.000000
# mean    8818.000000      0.780323         0.072923       -99888.459786
# std     5090.930334      1.226734         0.260018        46338.054529
# min        1.000000      0.000000         0.000000      -489416.000000
# 25%     4409.500000      0.000000         0.000000      -129480.000000
# 50%     8818.000000      0.000000         0.000000      -128320.000000
# 75%    13226.500000      1.000000         0.000000       -73675.250000
# max    17635.000000      4.000000         1.000000         3190.000000
#
#        maxDiffPostsDay        mobile        follow    thermo_Rep  \
# count     17292.000000  17635.000000  17635.000000  17097.000000
# mean         71.487913      0.628296      3.375503     27.535474
# std          29.390784      0.483274      0.741571     29.153207
# min          -1.000000      0.000000      0.000000      0.000000
# ...

# %%
survey = survey.dropna(subset=["polAffectiveIndex"])
survey
# Out:
#        Unnamed: 0         ResponseId     treatment matchTreatment  \
# 0               1  R_0006zeOG7m4r5bX       Liberal        Counter
# 2               3  R_006vNO79PBEQJK9       Liberal        Counter
# 3               4  R_00QUYdXn0LIx6sF       Control        Control
# 4               5  R_00VWiXSyP4IFidX       Control        Control
# 5               6  R_01cK08xkLSosPJf  Conservative        Counter
# ...           ...                ...           ...            ...
# 17630       17631  R_zf2l1Hew4SGGGpr  Conservative            Pro
# 17631       17632  R_zfeiEbwrxA57jrP       Control        Control
# 17632       17633  R_zfiOvlmPfCMWNRn  Conservative        Counter
# 17633       17634  R_zfj2X1JcX4Yc2Qx       Control        Control
# 17634       17635  R_zflZX23gkgzR2V3       Control        Control
#
#          treatIdeo  control  \
# 0      treatLIdeoC    False
# 2      treatLIdeoC    False
# 3          control     True
# 4          control     True
# ...

# %%
X = survey[["ideologyF", "partyAllF", "trumpF", "genderF", "ageWM", "ageSqWM", "ageHave", "ideoLeaningF", "matchTreatment", 
            "thermo_DiffWM", "thermo_DiffHave", "empathyDifficult_DiffHave",
            "empathyDifficult_DiffWM"]]
Y = survey["polAffectiveIndex"]

# %%
numeric_features = ["ageWM", "ageSqWM", "thermo_DiffWM", "empathyDifficult_DiffWM"]

categorical_features = ["ideologyF", "partyAllF", "trumpF", "genderF", "ideoLeaningF",
                        "ageHave", "thermo_DiffHave", "matchTreatment", "empathyDifficult_DiffHave",]  # one-hot encoded

# %%
preprocessor = ColumnTransformer(transformers=[
    ('num', StandardScaler(), numeric_features),
    ('cat', OneHotEncoder(drop='first'), categorical_features)
])

# %%
lasso_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('lasso', Lasso())
])

# %%
alphas = np.linspace(0.0001, 0.75, 50)  

param_grid = {
    "lasso__alpha": alphas  
}

cv = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
grid_search = GridSearchCV(
    lasso_pipeline,
    param_grid,
    cv=cv,
    scoring='neg_mean_squared_error',
    return_train_score=True)


grid_search.fit(X, Y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['ageWM',
#                                                                           'ageSqWM',
#                                                                           'thermo_DiffWM',
#                                                                           'empathyDifficult_DiffWM']),
#                                                                         ('cat',
#                                                                          OneHotEncoder(drop='first'),
#                                                                          ['ideologyF',
# ...

# %%
# Best parameters
print("Best alpha:", grid_search.best_params_['lasso__alpha'])
print("Best CV RMSE:", np.sqrt(-grid_search.best_score_))
# Out:
# Best alpha: 0.0001
# Best CV RMSE: 0.6521845502058116

# %%
# Extract results
results = grid_search.cv_results_
alphas = results['param_lasso__alpha'].data.astype(float)
mean_rmse = np.sqrt(-results['mean_test_score'])
std_rmse = results['std_test_score']

# %%
# Plot performance
plt.figure(figsize=(8, 5))
plt.plot(alphas, mean_rmse, marker='o', label="Mean CV RMSE")
plt.fill_between(alphas,
                 mean_rmse - std_rmse,
                 mean_rmse + std_rmse,
                 color='lightblue', alpha=0.5, label="±1 std dev")

plt.xlabel("Alpha")
plt.ylabel("RMSE")
plt.title("Lasso Regression Cross-Validation Performance")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Extract coefficients for each alpha
coefs = []

for alpha in alphas:
    lasso_pipeline.set_params(lasso__alpha=alpha)
    lasso_pipeline.fit(X, Y)
    # Get coefficients after preprocessing
    coefs.append(lasso_pipeline.named_steps['lasso'].coef_)

coefs = np.array(coefs)

feature_names = grid_search.best_estimator_.named_steps['preprocessor'].get_feature_names_out()

plt.figure(figsize=(8, 5))
for i, name in enumerate(feature_names):
    plt.plot(alphas, coefs[:, i], label=name)

plt.xlabel('Alpha')
plt.ylabel('Coefficient Value')
plt.title('Lasso Regression Coefficients vs Alpha')
plt.legend(loc='lower right', fontsize='x-small', ncol=2)
plt.tight_layout()
plt.show()

# %%
# Extract coefficients for each alpha
coefs = []

for alpha in alphas:
    lasso_pipeline.set_params(lasso__alpha=alpha)
    lasso_pipeline.fit(X, Y)
    coefs.append(lasso_pipeline.named_steps['lasso'].coef_)

coefs = np.array(coefs)

# Feature names
feature_names = grid_search.best_estimator_.named_steps['preprocessor'].get_feature_names_out()

# ---- NEW PART: select top 5 features by magnitude at lowest alpha ----
# lowest alpha is the least regularized
initial_coefs = coefs[0]               # coefficients at alpha = alphas[0]
top5_idx = np.argsort(np.abs(initial_coefs))[-5:]  # indices of 5 largest |coef|

top5_names = feature_names[top5_idx]
top5_coefs = coefs[:, top5_idx]

# ---- PLOT ONLY TOP 5 ----
plt.figure(figsize=(8, 5))

for i, name in enumerate(top5_names):
    plt.plot(alphas, top5_coefs[:, i], label=name)

plt.xlabel('Alpha')
plt.ylabel('Coefficient Value')
plt.title('Top 5 Lasso Coefficients vs Alpha')
plt.legend(loc='lower right', fontsize='small')
plt.tight_layout()
plt.show()
